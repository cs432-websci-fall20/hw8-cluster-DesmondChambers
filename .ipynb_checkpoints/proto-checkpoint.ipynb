# %%
import fnmatch
import os
import re

all_tweets_dict = {}

for file in os.listdir('./tweets/'):
    try:
        #if fnmatch.fnmatch(file, '*.txt'):
        print(file)
        my_file = open(f"./tweets/{file}", "r")
        content = my_file.read()
        globals()['{}'.format(file)] = content.split()
        my_file.close()
        #print(content_list)
        #for word in globals()[file]:
        all_tweets_dict['{}'.format(file)] = globals()['{}'.format(file)]
    except:
        continue
        
print(len(all_tweets_dict))
# Out:
# chrisbrown_tweets
# jimmyfallon_tweets
# BrunoMars_tweets
# MariahCarey_tweets
# BBCWorld_tweets
# HillaryClinton_tweets
# RealLamarOdom_tweets
# johnlegend_tweets
# BarackObama_tweets
# Tip_tweets
# SportsCenter_tweets
# kourtneykardash_tweets
# NASA_tweets
# JLo_tweets
# NFL_tweets
# Akon_tweets
# Ludacris_tweets
# serenawilliams_tweets
# khloekardashian_tweets
# instagram_tweets
# 50cent_tweets
# MichelleObama_tweets
# katyperry_tweets
# Reuters_tweets
# YouTube_tweets
# CNN_tweets
# TheEconomist_tweets
# britneyspears_tweets
# wizkhalifa_tweets
# ManUtd_tweets
# JessicaSimpson_tweets
# TreySongz_tweets
# onedirection_tweets
# DwightHoward_tweets
# kanyewest_tweets
# IAMQUEENLATIFAH_tweets
# MesutOzil1088_tweets
# NeYoCompound_tweets
# KevinHart4real_tweets
# BigSean_tweets
# aliciakeys_tweets
# nytimes_tweets
# tomhanks_tweets
# Schwarzenegger_tweets
# NBA_tweets
# cnnbrk_tweets
# chrisrock_tweets
# MileyCyrus_tweets
# nickjonas_tweets
# IGGYAZALEA_tweets
# joejonas_tweets
# ladygaga_tweets
# Google_tweets
# jimmykimmel_tweets
# PerezHilton_tweets
# NICKIMINAJ_tweets
# espn_tweets
# KimKardashian_tweets
# Oprah_tweets
# Harry_Styles_tweets
# pitbull_tweets
# AdamSchefter_tweets
# BBCBreaking_tweets
# Pharrell_tweets
# premierleague_tweets
# kobebryant_tweets
# FloydMayweather_tweets
# BillGates_tweets
# jtimberlake_tweets
# POTUS_tweets
# SHAQ_tweets
# coldplay_tweets
# selenagomez_tweets
# KendallJenner_tweets
# .ipynb_checkpoints
# realDonaldTrump_tweets
# Louis_Tomlinson_tweets
# ArianaGrande_tweets
# LilTunechi_tweets
# Usher_tweets
# blakeshelton_tweets
# zaynmalik_tweets
# elonmusk_tweets
# rihanna_tweets
# EmmaWatson_tweets
# KingJames_tweets
# TomCruise_tweets
# Tyga_tweets
# TheEllenShow_tweets
# ConanOBrien_tweets
# JColeNC_tweets
# Eminem_tweets
# KylieJenner_tweets
# ActuallyNPH_tweets
# Pink_tweets
# Adele_tweets
# NatGeo_tweets
# kendricklamar_tweets
# LiamPayne_tweets
# TheRock_tweets
# taylorswift13_tweets
# 100

# %%
print(chrisbrown_tweets)
# Out:
# ['RT', '@RCARecords:', 'MUSIC', 'VIDEO', 'OUT', 'NOW!💥💥💥', '@chrisbrown', 'x', '@youngthug', '🔗:', 'https://t.co/2BUewhcuhV', 'https://t.co/NgfhSR4VKP', 'RT', '@Vevo:', 'Grab', 'your', 'tickets,', 'this', 'is', 'a', 'whole', 'gangster', 'film!', '🎟️', 'Head', 'to', 'the', '1940s', 'with', '@chrisbrown', '&amp;', '@youngthug', 'in', '“City', 'Girls”', '⠀⠀⠀⠀⠀⠀⠀⠀⠀…', 'RT', '@XXL:', 'Chris', 'Brown', 'and', 'Young', 'Thug', 'went', 'all
://t.co/wsbF8htOHV', 'Check', 'out', 'the', 'video', 'for', '#SayYouLoveMe', 'now!', 'https://t.co/CkOV6Wbv0G', '#SAYYOULOVEME', 'https://t.co/fyAtg0uihT', 'RT', '@HOT97:', '"Say', 'You', 'Love', 'Me"', '🎥', '#ChrisBrown', '+', '#YoungThug', 'is', 'here!', '🔥', 'https://t.co/BPit9dTa27', 'SAY', 'YOU', 'LOVE', 'ME', 'video', 'is', 'available', 'on', '@YouTube', '&amp;', '@Vevo', 'now!', '@youngthug', 'https://t.co/fyAtg0uihT', 'https://t.co/jCcYpKMJ6o', 'RT', '@ComplexMusic:', '🎬', '@chrisbrown', 'and', '@youngthug', 'team', 'up', 'again', 'for', 'some', 'more', 'new', 'visuals.', 'Check', 'out', 'the', 'video', 'for', '#SayYouLoveMe:', 'https://t.c…', 'RT', '@RapUp:', 'Chris', 'Brown', 'and', 'Young', 'Thug', 'get', 'animated', 'in', 'the', 'video', 'for', '"Say', 'You', 'Love', 'Me."', 'Watch:', 'https://t.co/Wt457bCY2E', '🚀🪐', 'https://t.co/z92W8…', 'SAY', ...

# %%
import re

clean_tweets_dict = {}
temp_list = []  

def clean_up(title, list): 
    for word in list:
        try:
            result = re.sub(r"http\S+", "", "{}".format(word.strip()))
            result = re.sub(r"@\S+", "", "{}".format(result.strip()))
            result = result.replace('"','')
            test = ''.join(letter for letter in result.lower() if 'a' <= letter <= 'z')
            #print(test)
            if not len(test)<3 and not len(test) > 15:
                item = str(test)
                #print(test)
                temp_list.append(item)
        except:
            continue
    #globals()['{}'.format(word)]
    #all_clean_tweets['{}' .format(title)] = temp_list
    return temp_list

    #while("" in globals()['{}'.format(word)]) : 
        #globals()['{}'.format(word)].remove("") 
    #print(word)
    #print(len(globals()['{}'.format(word)]))
    #print(newlist)
    #all_clean_tweets.append(globals()['{}'.format(word)])

if __name__ == '__main__':
    for key, val in all_tweets_dict.items():   
        clean_tweets_dict['{}'.format(key)] = clean_up(key, val)
        #clean_up(key, val)"

# %%
for item in clean_tweets_dict:    
    print(item)
# Out:
# chrisbrown_tweets
# jimmyfallon_tweets
# BrunoMars_tweets
# MariahCarey_tweets
# BBCWorld_tweets
# HillaryClinton_tweets
# RealLamarOdom_tweets
# johnlegend_tweets
# BarackObama_tweets
# Tip_tweets
# SportsCenter_tweets
# kourtneykardash_tweets
# NASA_tweets
# JLo_tweets
# NFL_tweets
# Akon_tweets
# Ludacris_tweets
# serenawilliams_tweets
# khloekardashian_tweets
# instagram_tweets
# 50cent_tweets
# MichelleObama_tweets
# katyperry_tweets
# Reuters_tweets
# YouTube_tweets
# CNN_tweets
# TheEconomist_tweets
# britneyspears_tweets
# wizkhalifa_tweets
# ManUtd_tweets
# JessicaSimpson_tweets
# TreySongz_tweets
# onedirection_tweets
# DwightHoward_tweets
# kanyewest_tweets
# IAMQUEENLATIFAH_tweets
# MesutOzil1088_tweets
# NeYoCompound_tweets
# KevinHart4real_tweets
# BigSean_tweets
# aliciakeys_tweets
# nytimes_tweets
# tomhanks_tweets
# Schwarzenegger_tweets
# NBA_tweets
# cnnbrk_tweets
# chrisrock_tweets
# MileyCyrus_tweets
# nickjonas_tweets
# IGGYAZALEA_tweets
# joejonas_tweets
# ladygaga_tweets
# Google_tweets
# jimmykimmel_tweets
# PerezHilton_tweets
# NICKIMINAJ_tweets
# espn_tweets
# KimKardashian_tweets
# Oprah_tweets
# Harry_Styles_tweets
# pitbull_tweets
# AdamSchefter_tweets
# BBCBreaking_tweets
# Pharrell_tweets
# premierleague_tweets
# kobebryant_tweets
# FloydMayweather_tweets
# BillGates_tweets
# jtimberlake_tweets
# POTUS_tweets
# SHAQ_tweets
# coldplay_tweets
# selenagomez_tweets
# KendallJenner_tweets
# realDonaldTrump_tweets
# Louis_Tomlinson_tweets
# ArianaGrande_tweets
# LilTunechi_tweets
# Usher_tweets
# blakeshelton_tweets
# zaynmalik_tweets
# elonmusk_tweets
# rihanna_tweets
# EmmaWatson_tweets
# KingJames_tweets
# TomCruise_tweets
# Tyga_tweets
# TheEllenShow_tweets
# ConanOBrien_tweets
# JColeNC_tweets
# Eminem_tweets
# KylieJenner_tweets
# ActuallyNPH_tweets
# Pink_tweets
# Adele_tweets
# NatGeo_tweets
# kendricklamar_tweets
# LiamPayne_tweets
# TheRock_tweets
# taylorswift13_tweets

# %%
all_clean_tweets

# %%
import re

def getwordcounts(tweets):
    for word in tweets:
        wc.setdefault(word, 0)
        wc[word] += 1

    return ("{}".format(tweets), wc)

apcount = {}
wordcounts = {}
for item in all_clean_tweets:
    try:
        (title, wc) = getwordcounts(item)
        wordcounts[title] = wc
        for (word, count) in wc.items():
            apcount.setdefault(word, 0)
            if count > 1:
                apcount[word] += 1
    except:
        print ('Failed to parse feed %s' % item)

wordlist = []
for (w, bc) in apcount.items():
    frac = float(bc) / len(feedlist)
    if frac > 0.1 and frac < 0.5:
        wordlist.append(w)

#out = file('blogdata1.txt', 'w')
out = open('tweetdata.txt', 'w') 
out.write('Blog')
for word in wordlist:
    out.write('\t%s' % word)
out.write('\n')
for (blog, wc) in wordcounts.items():
    print (blog)
    out.write(blog)
    for word in wordlist:
        if word in wc:
            out.write('\t%d' % wc[word])
        else:
            out.write('\t0')
    out.write('\n')

# %%
# !pipenv install feedparser

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
import feedparser
import re

def getwordcounts(url):
    '''
    Returns title and dictionary of word counts for an RSS feed
    '''
    # Parse the feed
    d = feedparser.parse(url)
    wc = {}

    # Loop over all the entries
    for e in d.entries:
        if 'summary' in e:
            summary = e.summary

        else:
            summary = e.description

        # Extract a list of words
        words = getwords(e.title + ' ' + summary)
        for word in words:
            wc.setdefault(word, 0)
            wc[word] += 1

    return (d.feed.title, wc)


def getwords(html):
    # Remove all the HTML tags
    txt = re.compile(r'<[^>]+>').sub('', html)

    # Split words by all non-alpha characters
    words = re.compile(r'[^A-Z^a-z]+').split(txt)
    #print(words)
    # Convert to lowercase
    return [word.lower() for word in words if word != '']


apcount = {}
wordcounts = {}
file1 = open('feedlist.txt', 'r') 
feedlist = file1.readlines() 
  
count = 0
# Strips the newline character 
#for line in Lines: 
for feedurl in feedlist:
    try:
        (title, wc) = getwordcounts(feedurl)
        wordcounts[title] = wc
        for (word, count) in wc.items():
            apcount.setdefault(word, 0)
            if count > 1:
                apcount[word] += 1
    except:
        print ('Failed to parse feed %s' % feedurl)

wordlist = []
for (w, bc) in apcount.items():
    frac = float(bc) / len(feedlist)
    if frac > 0.1 and frac < 0.5:
        wordlist.append(w)

#file1 = open("MyFile.txt", "w") 
out = open("blogdata1.txt", "w") 
out.write('Blog')
for word in wordlist:
    out.write('\t%s' % word)
out.write('\n')
for (blog, wc) in wordcounts.items():
    print (blog)
    out.write(blog)
    for word in wordlist:
        if word in wc:
            out.write('\t%d' % wc[word])
        else:
            out.write('\t0')
    out.write('\n')
